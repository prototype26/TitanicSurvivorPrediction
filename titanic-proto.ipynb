# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier
import pandas_profiling
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import graphviz
from sklearn.ensemble import RandomForestClassifier

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
train_data = pd.read_csv("../input/titanic/train.csv")
test_data = pd.read_csv("../input/titanic/test.csv")


# Any results you write to the current directory are saved as output.
# train_data.describe()
# pandas_profiling.ProfileReport(train_data)
# train_data.isnull().sum().sort_values(ascending=False)
# train_data = train_data.drop(['PassengerId'],axis =1)
# train_data = train_data.drop(['Ticket'],axis = 1)
# train_data = train_data.drop(['Cabin'], axis=1)
# train_data = train_data.drop(['Name'],axis=1)
# train_data = train_data.drop(['Embarked'],axis = 1)
# # train_data.isnull().sum().sort_values(ascending=False)
# mean_Age = train_data['Age'].mean()

# print(mean_Age)
# train_data.fillna(mean_Age)
# genders ={"male" :0,"female":1}
# train_data.isnull().sum().sort_values(ascending=False)
# train_data['Sex'] = train_data['Sex'].map(genders)
# test_data['Sex'] = test_data['Sex'].map(genders)
# train_data.head(5)
# pandas_profiling.ProfileReport(train_data)
# X_train = train_data.drop(['Survived'],axis=1)

# X_train.fillna(24)

# Y_train = train_data['Survived']
# X_test = test_data.drop(['PassengerId'],axis=1).copy()

# X_test.columns.values
# X_train.head(10)
# X_train.isnull().sum()
# X_train = X_train.drop(['Parch'],axis=1)
# mean_age = X_train['Age'].mean()
# median_age = X_train['Age'].median()
# data = []
# print(median_age)
# print(mean_age)
# X_train = X_train.fillna(mean_age)

# #logistic Regression model


# # Y_predict = logreg.predict(X_test)
# # print(Y_predict)

# logreg = LogisticRegression(solver='lbfgs')
# logreg.fit(X_train,Y_train)
# accuracy_logReg = round(logreg.score(X_train,Y_train)*100, 2)
# print(accuracy_logReg)
# #neuron model perceptron model
# perceptron = Perceptron(max_iter=5)
# perceptron.fit(X_train,Y_train)
# print(round(perceptron.score(X_train, Y_train)*100),2)
# #decision tree classifier
# decision_tree = DecisionTreeClassifier()
# decision_tree.fit(X_train,Y_train)

# data = export_graphviz(decision_tree, out_file=None, filled=True, rounded=True,special_characters=True)
# graph = graphviz.Source(data)
# graph
# print(cross_val_score(decision_tree, X_train, Y_train, cv=3).mean()*100)  
# #decision tree classifier
# decision_tree = DecisionTreeClassifier()
# decision_tree.fit(X_train,Y_train)

# data = export_graphviz(decision_tree, out_file=None, filled=True, rounded=True,special_characters=True)
# graph = graphviz.Source(data)
# graph
# print(cross_val_score(decision_tree, X_train, Y_train, cv=3).mean()*100)  
# #random forest classifier
# random_forest = RandomForestClassifier(n_estimators=200,oob_score = True)
# random_forest.fit(X_train,Y_train)
# # print(cross_val_score(random_forest, X_train, Y_train, cv=3).mean()*100)  
# acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
# print(round(acc_random_forest,2,), "%")

# %%
train_data.isnull().sum().sort_values(ascending=False)

# %%
train_data = train_data.drop(['PassengerId'],axis =1)

# %%
train_data = train_data.drop(['Ticket'],axis = 1)
train_data = train_data.drop(['Cabin'], axis=1)
train_data = train_data.drop(['Name'],axis=1)
train_data = train_data.drop(['Embarked'],axis = 1)

# %%
# train_data.isnull().sum().sort_values(ascending=False)
mean_Age = train_data['Age'].mean()

# print(mean_Age)

# %%
train_data.fillna(mean_Age)
# train_data.isnull().sum().sort_valu

# %%
genders ={"male" :0,"female":1}
# train_data.isnull().sum().sort_values(ascending=False)

# %%
train_data['Sex'] = train_data['Sex'].map(genders)
test_data['Sex'] = test_data['Sex'].map(genders)
# train_data.head(5)
# pandas_profiling.ProfileReport(train_data)

# %%
X_train = train_data.drop(['Survived'],axis=1)

X_train.fillna(24)

Y_train = train_data['Survived']
X_test = test_data.drop(['PassengerId'],axis=1).copy()

X_test.columns.values

# %%
X_train.isnull().sum()
X_train = X_train.drop(['Parch'],axis=1)

# %%
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()
data = []
print(median_age)
print(mean_age)
X_train = X_train.fillna(mean_age)

#logistic Regression model


# Y_predict = logreg.predict(X_test)
# print(Y_predict)

# %%
logreg = LogisticRegression(solver='lbfgs')
logreg.fit(X_train,Y_train)

# %%
accuracy_logReg = round(logreg.score(X_train,Y_train)*100, 2)
print(accuracy_logReg)

# %%
#neuron model perceptron model
X_train,X_test,Y_train,Y_test = 
perceptron = Perceptron(max_iter=5)


perceptron.fit(X_train,Y_train)
print(round(perceptron.score(X_train, Y_train)*100),2)

# %%
#decision tree classifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train,Y_train)

data = export_graphviz(decision_tree, out_file=None, filled=True, rounded=True,special_characters=True)
graph = graphviz.Source(data)
graph
print(cross_val_score(decision_tree, X_train, Y_train, cv=3).mean()*100)

# %%
#random forest classifier
random_forest = RandomForestClassifier(n_estimators=200,oob_score = True)
random_forest.fit(X_train,Y_train)
# print(cross_val_score(random_forest, X_train, Y_train, cv=3).mean()*100)  
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
print(round(acc_random_forest,2,), "%")
